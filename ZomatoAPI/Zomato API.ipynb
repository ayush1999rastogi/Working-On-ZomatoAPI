# %%
#API Key - 03ae459a8a0fb288b359ff5632b97fad

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
a=requests.get('https://developers.zomato.com/api/v2.1/categories' ,headers = {'user-key': '03ae459a8a0fb288b359ff5632b97fad','content-type': 'application/json'} )

# %%
a
# Out:
# <Response [200]>

# %%
a.text
print(a.url)
# Out:
# https://developers.zomato.com/api/v2.1/categories

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
a=requests.get('https://developers.zomato.com/api/v2.1/search' ,headers = {'Accept': 'application/json','user-key': '03ae459a8a0fb288b359ff5632b97fad'},params = {'entity_id':104,'entity_type':'subzone','cuisines':73,'count':10,'sort':'rating','order':'desc'} )
print(a.status_code)
print(a.url)
py_data = a.json()
# Out:
# 200
# https://developers.zomato.com/api/v2.1/search?entity_id=104&entity_type=subzone&cuisines=73&count=10&sort=rating&order=desc

# %%
py_data
# Out:
# {'results_found': 56,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': 1,
#       'takeaway': -1},
#      'res_id': 18246991},
#     'apikey': '03ae459a8a0fb288b359ff5632b97fad',
#     'id': '18246991',
#     'name': 'Odeon Social',
#     'url': 'https://www.zomato.com/OdeonSocial?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '23, 1st Floor, Odeon Building, Radial 5, D Block, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6343906062',
#      'longitude': '77.2208622471',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, Chinese, Biryani, American, Continental',
#     'timings': '10am – 12:30AM (Mon, Tue, Thu, Fri, Sat, Sun), 11am – 12:30AM (Wed)',
# ...

# %%
for i in py_data['restaurants']:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'])
# Out:
# Odeon Social 4.7 18246991
# 38 Barracks 4.7 18241537
# Ministry Of Beer 4.6 18418277
# Chili's Grill & Bar 4.5 18537536
# The Darzi Bar & Kitchen 4.4 18423151
# Station Bar 4.4 18851371
# Detroit 4.4 18625812
# Xero Degrees 4.4 18729557
# The Art House Bar n Cafe 4.4 18863766
# The Luggage Room Kitchen And Bar 4.3 18337893

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
a=requests.get('https://developers.zomato.com/api/v2.1/locations' ,headers = {'Accept': 'application/json','user-key': '03ae459a8a0fb288b359ff5632b97fad'},params = {'query':'Connaught Place'} )
print(a.status_code)
print(a.text)
# Out:
# 200
# {"location_suggestions":[{"entity_type":"subzone","entity_id":104,"title":"Connaught Place, New Delhi","latitude":28.632832,"longitude":77.219688,"city_id":1,"city_name":"Delhi NCR","country_id":1,"country_name":"India"}],"status":"success","has_more":0,"has_total":0,"user_has_addresses":true}

# %%
py_data = a.json()

# %%
py_data
# Out:
# {'location_suggestions': [{'entity_type': 'subzone',
#    'entity_id': 104,
#    'title': 'Connaught Place, New Delhi',
#    'latitude': 28.632832,
#    'longitude': 77.219688,
#    'city_id': 1,
#    'city_name': 'Delhi NCR',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
for i in py_data['location_suggestions']:
    print(i['entity_type']," ",i['entity_id'])
# Out:
# subzone   104
